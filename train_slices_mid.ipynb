# %%
# %matplotlib inline

import os
import statistics

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import scipy.ndimage as ndimage
import torch

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T

from model import OctNet

# %%
PROCESSED_DATA_PATH = '../oct-data/data-2'

# %%
class OctDataset(Dataset):
    def __init__(self, split):
        pos_dir = os.path.join(PROCESSED_DATA_PATH, split, 'pos')
        pos_paths = [os.path.join(pos_dir, f) for f in os.listdir(pos_dir)]
        
        neg_dir = os.path.join(PROCESSED_DATA_PATH, split, 'neg')
        neg_paths = [os.path.join(neg_dir, f) for f in os.listdir(neg_dir)]
        
        self.cube_paths = pos_paths + neg_paths
        self.labels = [1] * len(pos_paths) + [0] * len(neg_paths)
        
        self.transforms = T.Compose([
            T.ToTensor()
        ])
        
        assert len(self.labels) == len(self.cube_paths)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, i):
        slice_ = np.load(self.cube_paths[i])
        label = self.labels[i]
        img = Image.fromarray(slice_)
        return torch.FloatTensor(self.transforms(img)), label

# %%
train_dataset = OctDataset('train')
val_dataset = OctDataset('val')
test_dataset = OctDataset('test')

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=8)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=True, num_workers=8)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=True, num_workers=8)

# %%
net = OctNet().cuda()

for epoch in range(200):
    print(f'Epoch {epoch}')
    losses = []
    for X, y in train_loader:
        y = y.float()
        X_var = Variable(X, requires_grad=False).cuda()
        y_var = Variable(y, requires_grad=False).cuda()
        loss = net.train_step(X_var, y_var)
        # print(f'BCE loss = {loss.data[0]}')
        losses.append(loss.data[0])
    avg_loss = statistics.mean(losses)
    print(f'Avg BCE loss = {avg_loss}')
    
    num_correct, num_total = 0, 0
    for X, y in val_loader:
        preds = (net(Variable(X, volatile=True).cuda()) > 0.5).data.cpu().numpy()
        y = y.numpy()
        num_correct += sum(preds == y)
        num_total += len(y)
    print(f'Val accuracy: {num_correct} of {num_total} | {num_correct / num_total:.2f}')
# Out:
# Epoch 0
# Avg BCE loss = 1.3795386367485303
# Val accuracy: 33 of 65 | 0.51
# Epoch 1
# Avg BCE loss = 0.9116366449273935
# Val accuracy: 23 of 65 | 0.35
# Epoch 2
# Avg BCE loss = 0.8483347982919517
# Val accuracy: 38 of 65 | 0.58
# Epoch 3
# Avg BCE loss = 0.7111889717458677
# Val accuracy: 34 of 65 | 0.52
# Epoch 4
# Avg BCE loss = 0.5373851070884897
# Val accuracy: 31 of 65 | 0.48
# Epoch 5
# Avg BCE loss = 0.4469903622980879
# Val accuracy: 36 of 65 | 0.55
# Epoch 6
# Avg BCE loss = 0.3753434031137398
# Val accuracy: 37 of 65 | 0.57
# Epoch 7
# Avg BCE loss = 0.29712805577686857
# Val accuracy: 28 of 65 | 0.43
# Epoch 8
# Avg BCE loss = 0.2972377981020122
# Val accuracy: 33 of 65 | 0.51
# Epoch 9
# Avg BCE loss = 0.11591688241465252
# Val accuracy: 33 of 65 | 0.51
# Epoch 10
# Avg BCE loss = 0.058581971500788914
# Val accuracy: 32 of 65 | 0.49
# Epoch 11
# Avg BCE loss = 0.02728327382121141
# Val accuracy: 35 of 65 | 0.54
# Epoch 12
# Avg BCE loss = 0.016628504063574082
# Val accuracy: 34 of 65 | 0.52
# Epoch 13
# Avg BCE loss = 0.012246684705400291
# Val accuracy: 33 of 65 | 0.51
# Epoch 14
# Avg BCE loss = 0.017647827135109415
# Val accuracy: 39 of 65 | 0.60
# Epoch 15
# Avg BCE loss = 0.004964944203149434
# Val accuracy: 39 of 65 | 0.60
# Epoch 16
# Avg BCE loss = 0.0038402151510103784
# Val accuracy: 38 of 65 | 0.58
# Epoch 17
# Avg BCE loss = 0.0029241176901244315
# Val accuracy: 38 of 65 | 0.58
# Epoch 18
# Avg BCE loss = 0.0023749869487037054
# Val accuracy: 37 of 65 | 0.57
# Epoch 19
# Avg BCE loss = 0.00206145055312272
# Val accuracy: 39 of 65 | 0.60
# Epoch 20
# Avg BCE loss = 0.001740351240561508
# Val accuracy: 37 of 65 | 0.57
# Epoch 21
# Avg BCE loss = 0.0014618420232373032
# Val accuracy: 39 of 65 | 0.60
# Epoch 22
# Avg BCE loss = 0.0013075949640811554
# Val accuracy: 38 of 65 | 0.58
# Epoch 23
# Avg BCE loss = 0.0010958221633899019
# Val accuracy: 41 of 65 | 0.63
# Epoch 24
# Avg BCE loss = 0.0009530632812412409
# Val accuracy: 42 of 65 | 0.65
# Epoch 25
# Avg BCE loss = 0.00091459891932993
# Val accuracy: 38 of 65 | 0.58
# Epoch 26
# Avg BCE loss = 0.000777497497033093
# Val accuracy: 37 of 65 | 0.57
# Epoch 27
# Avg BCE loss = 0.0006989706922743172
# Val accuracy: 39 of 65 | 0.60
# Epoch 28
# Avg BCE loss = 0.0006366586483850636
# Val accuracy: 35 of 65 | 0.54
# Epoch 29
# Avg BCE loss = 0.0006271013145055231
# Val accuracy: 40 of 65 | 0.62
# Epoch 30
# Avg BCE loss = 0.0005324889276961272
# Val accuracy: 39 of 65 | 0.60
# Epoch 31
# Avg BCE loss = 0.0004920402709042513
# Val accuracy: 41 of 65 | 0.63
# Epoch 32
# Avg BCE loss = 0.0004489479967766684
# Val accuracy: 39 of 65 | 0.60
# Epoch 33
# Avg BCE loss = 0.0003876498856453593
# Val accuracy: 40 of 65 | 0.62
# Epoch 34
# Avg BCE loss = 0.0003227849319496998
# Val accuracy: 39 of 65 | 0.60
# Epoch 35
# Avg BCE loss = 0.0003195233770720504
# Val accuracy: 41 of 65 | 0.63
# Epoch 36
# Avg BCE loss = 0.00028313193255018036
# Val accuracy: 40 of 65 | 0.62
# Epoch 37
# Avg BCE loss = 0.00028808949670036313
# Val accuracy: 40 of 65 | 0.62
# Epoch 38
# Avg BCE loss = 0.0002404710926881506
# Val accuracy: 41 of 65 | 0.63
# Epoch 39
# Avg BCE loss = 0.00022600073055041358
# Val accuracy: 39 of 65 | 0.60
# Epoch 40
# Avg BCE loss = 0.00020426196370106542
# Val accuracy: 39 of 65 | 0.60
# Epoch 41
# Avg BCE loss = 0.00018530769360216508
# Val accuracy: 38 of 65 | 0.58
# Epoch 42
# Avg BCE loss = 0.00017029356894752464
# Val accuracy: 40 of 65 | 0.62
# Epoch 43
# Avg BCE loss = 0.00015098196415826403
# Val accuracy: 42 of 65 | 0.65
# Epoch 44
# Avg BCE loss = 0.00014434312513057033
# Val accuracy: 38 of 65 | 0.58
# Epoch 45
# Avg BCE loss = 0.00013844138353122907
# Val accuracy: 41 of 65 | 0.63
# Epoch 46
# Avg BCE loss = 0.00012587385153434115
# Val accuracy: 41 of 65 | 0.63
# Epoch 47
# Avg BCE loss = 0.00011202992171077488
# Val accuracy: 38 of 65 | 0.58
# Epoch 48
# Avg BCE loss = 0.00011022583860439295
# Val accuracy: 39 of 65 | 0.60
# Epoch 49
# Avg BCE loss = 9.9549628078826e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 50
# Avg BCE loss = 9.883450687030905e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 51
# Avg BCE loss = 9.183635803547535e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 52
# Avg BCE loss = 7.307916417294338e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 53
# Avg BCE loss = 7.512644449644624e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 54
# Avg BCE loss = 6.709669745943466e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 55
# Avg BCE loss = 6.463659969192711e-05
# Val accuracy: 36 of 65 | 0.55
# Epoch 56
# Avg BCE loss = 5.7882572197259456e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 57
# Avg BCE loss = 5.7182842528079675e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 58
# Avg BCE loss = 5.0594282217060624e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 59
# Avg BCE loss = 4.633224255355474e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 60
# Avg BCE loss = 4.291971176940979e-05
# Val accuracy: 37 of 65 | 0.57
# Epoch 61
# Avg BCE loss = 4.3625975554239614e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 62
# Avg BCE loss = 3.752529388874478e-05
# Val accuracy: 37 of 65 | 0.57
# Epoch 63
# Avg BCE loss = 3.2601134095609015e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 64
# Avg BCE loss = 3.3819303847421374e-05
# Val accuracy: 37 of 65 | 0.57
# Epoch 65
# Avg BCE loss = 3.101257228257307e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 66
# Avg BCE loss = 2.9760504256948114e-05
# Val accuracy: 39 of 65 | 0.60
# Epoch 67
# Avg BCE loss = 3.177437851141391e-05
# Val accuracy: 37 of 65 | 0.57
# Epoch 68
# Avg BCE loss = 2.4664237143417052e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 69
# Avg BCE loss = 2.43963726492087e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 70
# Avg BCE loss = 2.0110394569262306e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 71
# Avg BCE loss = 1.9314001548548374e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 72
# Avg BCE loss = 1.716882968498756e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 73
# Avg BCE loss = 1.895503070779089e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 74
# Avg BCE loss = 1.8312398875239814e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 75
# Avg BCE loss = 1.4838647878016619e-05
# Val accuracy: 40 of 65 | 0.62
# Epoch 76
# Avg BCE loss = 1.2983735373114433e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 77
# Avg BCE loss = 1.2115482172894266e-05
# Val accuracy: 41 of 65 | 0.63
# Epoch 78
# Avg BCE loss = 1.2171289885556398e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 79
# Avg BCE loss = 1.2244344606103881e-05
# Val accuracy: 38 of 65 | 0.58
# Epoch 80
# Avg BCE loss = 1.0872829202029407e-05
# Val accuracy: 41 of 65 | 0.63
# Epoch 81
# Avg BCE loss = 9.97464981044671e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 82
# Avg BCE loss = 9.14809229738346e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 83
# Avg BCE loss = 9.526829020263399e-06
# Val accuracy: 36 of 65 | 0.55
# Epoch 84
# Avg BCE loss = 8.506716016536073e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 85
# Avg BCE loss = 7.521760946336817e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 86
# Avg BCE loss = 7.676271976577924e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 87
# Avg BCE loss = 7.255419379033497e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 88
# Avg BCE loss = 6.401064500768821e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 89
# Avg BCE loss = 6.2662003053347465e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 90
# Avg BCE loss = 5.748551111460953e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 91
# Avg BCE loss = 5.222494353672248e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 92
# Avg BCE loss = 4.983093482078708e-06
# Val accuracy: 39 of 65 | 0.60
# Epoch 93
# Avg BCE loss = 5.174924063496537e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 94
# Avg BCE loss = 4.628222267028297e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 95
# Avg BCE loss = 4.1587784906124484e-06
# Val accuracy: 35 of 65 | 0.54
# Epoch 96
# Avg BCE loss = 4.20636174108766e-06
# Val accuracy: 36 of 65 | 0.55
# Epoch 97
# Avg BCE loss = 4.097663244878078e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 98
# Avg BCE loss = 3.56887351283164e-06
# Val accuracy: 40 of 65 | 0.62
# Epoch 99
# Avg BCE loss = 3.430381472960008e-06
# Val accuracy: 40 of 65 | 0.62
# Epoch 100
# Avg BCE loss = 3.206866966963901e-06
# Val accuracy: 36 of 65 | 0.55
# Epoch 101
# Avg BCE loss = 3.3915623216977233e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 102
# Avg BCE loss = 3.273725105216482e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 103
# Avg BCE loss = 2.9119735474615335e-06
# Val accuracy: 39 of 65 | 0.60
# Epoch 104
# Avg BCE loss = 2.7911373187745857e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 105
# Avg BCE loss = 2.444408338561982e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 106
# Avg BCE loss = 2.4555531786827793e-06
# Val accuracy: 39 of 65 | 0.60
# Epoch 107
# Avg BCE loss = 2.144259141203736e-06
# Val accuracy: 37 of 65 | 0.57
# Epoch 108
# Avg BCE loss = 2.2024840266284696e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 109
# Avg BCE loss = 2.0485903742523453e-06
# Val accuracy: 39 of 65 | 0.60
# Epoch 110
# Avg BCE loss = 2.2861279290247863e-06
# Val accuracy: 35 of 65 | 0.54
# Epoch 111
# Avg BCE loss = 2.122844666901609e-06
# Val accuracy: 35 of 65 | 0.54
# Epoch 112
# Avg BCE loss = 2.505380750876191e-06
# Val accuracy: 38 of 65 | 0.58
# Epoch 113
# Avg BCE loss = 1.973457602509691e-06
# Val accuracy: 36 of 65 | 0.55
# Epoch 114
# Avg BCE loss = 1.976202954302462e-06
# Val accuracy: 35 of 65 | 0.54
# Epoch 115
# Avg BCE loss = 0.685965531920738
# Val accuracy: 36 of 65 | 0.55
# Epoch 116
# Avg BCE loss = 0.16136878742953809
# Val accuracy: 34 of 65 | 0.52
# Epoch 117
# Avg BCE loss = 0.030150328193470334
# Val accuracy: 33 of 65 | 0.51
# Epoch 118
# Avg BCE loss = 0.011740373094378337
# Val accuracy: 33 of 65 | 0.51
# Epoch 119
# Avg BCE loss = 0.002669982588654306
# Val accuracy: 34 of 65 | 0.52
# Epoch 120
# Avg BCE loss = 0.0020143606637270943
# Val accuracy: 34 of 65 | 0.52
# Epoch 121
# Avg BCE loss = 0.0013058040124274196
# Val accuracy: 34 of 65 | 0.52
# Epoch 122
# Avg BCE loss = 0.0010357047522273268
# Val accuracy: 34 of 65 | 0.52
# Epoch 123
# Avg BCE loss = 0.0008347794972592476
# Val accuracy: 33 of 65 | 0.51
# Epoch 124
# Avg BCE loss = 0.0007671342512466476
# Val accuracy: 33 of 65 | 0.51
# Epoch 125
# Avg BCE loss = 0.0006499052342558632
# Val accuracy: 33 of 65 | 0.51
# Epoch 126
# Avg BCE loss = 0.0006499331439732762
# Val accuracy: 34 of 65 | 0.52
# Epoch 127
# Avg BCE loss = 0.0005794030239026868
# Val accuracy: 34 of 65 | 0.52
# Epoch 128
# Avg BCE loss = 0.0004460478987250802
# Val accuracy: 33 of 65 | 0.51
# Epoch 129
# Avg BCE loss = 0.00043700622458758316
# Val accuracy: 32 of 65 | 0.49
# Epoch 130
# Avg BCE loss = 0.0003874132590612471
# Val accuracy: 33 of 65 | 0.51
# Epoch 131
# Avg BCE loss = 0.00034152674326084223
# Val accuracy: 35 of 65 | 0.54
# Epoch 132
# Avg BCE loss = 0.0002986853900392434
# Val accuracy: 34 of 65 | 0.52
# Epoch 133
# Avg BCE loss = 0.0003212089745715229
# Val accuracy: 34 of 65 | 0.52
# Epoch 134
# Avg BCE loss = 0.00027868105389032034
# Val accuracy: 34 of 65 | 0.52
# Epoch 135
# Avg BCE loss = 0.0002586795622433982
# Val accuracy: 33 of 65 | 0.51
# Epoch 136
# Avg BCE loss = 0.00023304322397763383
# Val accuracy: 33 of 65 | 0.51
# Epoch 137
# Avg BCE loss = 0.00022880410561360078
# Val accuracy: 32 of 65 | 0.49
# Epoch 138
# Avg BCE loss = 0.00019042625760502073
# Val accuracy: 34 of 65 | 0.52
# Epoch 139
# Avg BCE loss = 0.0001831939096045054
# Val accuracy: 36 of 65 | 0.55
# Epoch 140
# Avg BCE loss = 0.00017341292480240622
# Val accuracy: 34 of 65 | 0.52
# Epoch 141
# Avg BCE loss = 0.0001528457705105876
# Val accuracy: 33 of 65 | 0.51
# Epoch 142
# Avg BCE loss = 0.00013981426462184778
# Val accuracy: 33 of 65 | 0.51
# Epoch 143
# Avg BCE loss = 0.0001469870971233541
# Val accuracy: 32 of 65 | 0.49
# Epoch 144
# Avg BCE loss = 0.0001385112879512892
# Val accuracy: 34 of 65 | 0.52
# Epoch 145
# Avg BCE loss = 0.0001234091033293531
# Val accuracy: 32 of 65 | 0.49
# Epoch 146
# Avg BCE loss = 0.00011433632151528698
# Val accuracy: 34 of 65 | 0.52
# Epoch 147
# Avg BCE loss = 0.00010768568578338595
# Val accuracy: 31 of 65 | 0.48
# Epoch 148
# Avg BCE loss = 0.00015634035399602334
# Val accuracy: 31 of 65 | 0.48
# Epoch 149
# Avg BCE loss = 0.00011702736738896863
# Val accuracy: 32 of 65 | 0.49
# Epoch 150
# Avg BCE loss = 8.190652290006958e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 151
# Avg BCE loss = 7.306008762427399e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 152
# Avg BCE loss = 8.840732052627543e-05
# Val accuracy: 35 of 65 | 0.54
# Epoch 153
# Avg BCE loss = 6.383098292751717e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 154
# Avg BCE loss = 5.974629324050855e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 155
# Avg BCE loss = 5.81120165934255e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 156
# Avg BCE loss = 5.915617111131418e-05
# Val accuracy: 36 of 65 | 0.55
# Epoch 157
# Avg BCE loss = 5.668320697065205e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 158
# Avg BCE loss = 4.714821155351526e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 159
# Avg BCE loss = 5.109351703889415e-05
# Val accuracy: 32 of 65 | 0.49
# Epoch 160
# Avg BCE loss = 3.932119369808391e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 161
# Avg BCE loss = 4.097703768981292e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 162
# Avg BCE loss = 3.783425782563702e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 163
# Avg BCE loss = 4.1478960731504176e-05
# Val accuracy: 31 of 65 | 0.48
# Epoch 164
# Avg BCE loss = 3.2039805769998856e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 165
# Avg BCE loss = 3.440009681178387e-05
# Val accuracy: 31 of 65 | 0.48
# Epoch 166
# Avg BCE loss = 2.99000034370509e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 167
# Avg BCE loss = 2.9844143449461152e-05
# Val accuracy: 30 of 65 | 0.46
# Epoch 168
# Avg BCE loss = 2.8384328051739248e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 169
# Avg BCE loss = 2.4966116074547016e-05
# Val accuracy: 31 of 65 | 0.48
# Epoch 170
# Avg BCE loss = 2.3123307992595256e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 171
# Avg BCE loss = 2.1625037582552288e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 172
# Avg BCE loss = 2.056556904255344e-05
# Val accuracy: 32 of 65 | 0.49
# Epoch 173
# Avg BCE loss = 2.0168202788127708e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 174
# Avg BCE loss = 1.7413409494554247e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 175
# Avg BCE loss = 1.6738291392089997e-05
# Val accuracy: 32 of 65 | 0.49
# Epoch 176
# Avg BCE loss = 1.7853228021086587e-05
# Val accuracy: 31 of 65 | 0.48
# Epoch 177
# Avg BCE loss = 1.391520997378179e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 178
# Avg BCE loss = 1.4254529690203657e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 179
# Avg BCE loss = 1.116173568731915e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 180
# Avg BCE loss = 1.126231985140561e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 181
# Avg BCE loss = 1.0457557942274679e-05
# Val accuracy: 34 of 65 | 0.52
# Epoch 182
# Avg BCE loss = 1.6798198441943024e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 183
# Avg BCE loss = 3.124503268449984e-05
# Val accuracy: 33 of 65 | 0.51
# Epoch 184
# Avg BCE loss = 9.52427627642449e-06
# Val accuracy: 33 of 65 | 0.51
# Epoch 185
# Avg BCE loss = 8.334344722946398e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 186
# Avg BCE loss = 8.097213345390933e-06
# Val accuracy: 33 of 65 | 0.51
# Epoch 187
# Avg BCE loss = 7.296059600455064e-06
# Val accuracy: 33 of 65 | 0.51
# Epoch 188
# Avg BCE loss = 6.903767673960095e-06
# Val accuracy: 31 of 65 | 0.48
# Epoch 189
# Avg BCE loss = 6.405117779504813e-06
# Val accuracy: 31 of 65 | 0.48
# Epoch 190
# Avg BCE loss = 5.911565199694603e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 191
# Avg BCE loss = 5.955256891438159e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 192
# Avg BCE loss = 5.1069133441993444e-06
# Val accuracy: 33 of 65 | 0.51
# Epoch 193
# Avg BCE loss = 5.429696445481423e-06
# Val accuracy: 33 of 65 | 0.51
# Epoch 194
# Avg BCE loss = 4.611297732813496e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 195
# Avg BCE loss = 4.427359566811558e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 196
# Avg BCE loss = 5.10598430587035e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 197
# Avg BCE loss = 3.899442982638452e-06
# Val accuracy: 32 of 65 | 0.49
# Epoch 198
# Avg BCE loss = 3.649376497964984e-06
# Val accuracy: 33 of 65 | 0.51
# Epoch 199
# Avg BCE loss = 3.4291185320895435e-06
# Val accuracy: 32 of 65 | 0.49
